# %%
from nsepython import *
running_status()
# Out:
# False

# %%
if(running_status()==True):
    print("Running...")

# %%
from nsepython import * 

#Getting All the Necessary Variables

historical_data = nsefetch('https://www.nseindia.com/api/historical/fo/derivatives?&expiryDate=24-SEP-2020&instrumentType=FUTIDX&symbol=BANKNIFTY')
historical_data = pd.DataFrame(historical_data['data'])
previous_day_high = historical_data['FH_TRADE_HIGH_PRICE'].iloc[0]
previous_day_low = historical_data['FH_TRADE_LOW_PRICE'].iloc[0]

banknifty_info=nsefetch("https://www.nseindia.com/api/equity-stockIndices?index=NIFTY%20BANK")
range_high = banknifty_info['data'][0]['dayHigh']
range_low = banknifty_info['data'][0]['dayLow']
opening_range = range_high-range_low

golden_number = (float(previous_day_high)-float(previous_day_low)+opening_range)*.618

previous_day_close = banknifty_info['data'][0]['previousClose']
buy_above = int(previous_day_close+golden_number)
sell_below = int(previous_day_close-golden_number)

print("Buy BankNIFTY Above: "+str(buy_above)+".")
print("Sell BankNIFTY Below: "+str(sell_below)+".")

#Entering the Trade

while True: 
    bn_ltp = nse_quote_ltp("BANKNIFTY")
    print("Current Value of BankNIFTY: " + str(bn_ltp))
    
    who_triggered = "NONE"
    
    #Amit's Test
    bn_ltp = 23031
    
    if(bn_ltp>buy_above):
        print("Buy Order executed at: " +str(bn_ltp)+". Entry Time is "+ str(run_time)+".")
        who_triggered = "BUY"
        stop_loss = bn_ltp*(.995)
        target = bn_ltp*(1.02)
    
    if(bn_ltp<sell_below):
        print("Sell Order executed at: " +str(bn_ltp)+". Entry Time is "+ str(run_time)+".")
        who_triggered = "Sell"
        stop_loss = bn_ltp*(1.005)
        target = bn_ltp*(.98)
    
    if(who_triggered != "NONE"):
        entry_price = run_time
        entry_price = bn_ltp
        print("Stop Loss is: " + str(stop_loss)+".")
        print("Target is: " + str(target)+".")
        break        
        
    time.sleep(10)

#Managing the Trade

while True:
    bn_ltp = nse_quote_ltp("BANKNIFTY")
    print("Current Value of BankNIFTY: " + str(bn_ltp))
    
    exit_time = run_time
    exit_price = bn_ltp
        
    if(who_triggered == "BUY"):
        
        if(bn_ltp>target):
            print("Target hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Profit: "+str(abs(entry_price-exit_price))+" points.")
            break
            
        if(bn_ltp<stop_loss):
            print("Stop Loss hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Loss: "+str(abs(entry_price-exit_price))+" points.")
            break
    
    if(who_triggered == "SELL"):
        
        if(bn_ltp<target):
            print("Target hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Profit: "+str(abs(entry_price-exit_price))+" points.")
            break
            
        if(bn_ltp>stop_loss):
            print("Stop Loss hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Loss: "+str(abs(entry_price-exit_price))+" points.")
            break
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/fo/derivatives?&expiryDate=24-SEP-2020&instrumentType=FUTIDX&symbol=BANKNIFTY HTTP/1.1" 200 2107
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=NIFTY%20BANK HTTP/1.1" 200 2841
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# Buy BankNIFTY Above: 23030.
# Sell BankNIFTY Below: 21902.
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 128683
# Current Value of BankNIFTY: 22479.95
# Buy Order executed at: 23031. Entry Time is 2020-09-14 02:23:29.293291.
# Stop Loss is: 22915.845.
# Target is: 23491.62.
# Current Value of BankNIFTY: 22479.95
# Stop Loss hit at: 22479.95. Exit Time is 2020-09-14 02:23:29.293291.
# Net Loss: 551.0499999999993 points.

# %%
banknifty_info=nsefetch("https://www.nseindia.com/api/equity-stockIndices?index=NIFTY%20BANK")
range_high = banknifty_info['data'][0]['dayHigh']
range_low = banknifty_info['data'][0]['dayLow']
opening_range = range_high-range_low

golden_number = (float(previous_day_high)-float(previous_day_low)+opening_range)*.618

previous_day_close = banknifty_info['data'][0]['previousClose']

# %%
nse_fno("BANKNIFTY")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 None
# {'info': {'symbol': 'BANKNIFTY',
#   'companyName': 'BANKNIFTY',
#   'identifier': 'none',
#   'activeSeries': [],
#   'debtSeries': [],
#   'isFNOSec': True,
#   'isCASec': False,
#   'isSLBSec': False,
#   'isDebtSec': False,
#   'isSuspended': False},
#  'filter': {'expiryDate': 'Invalid date', 'strikePrice': ''},
#  'underlyingValue': 22479.95,
#  'vfq': 2501,
#  'fut_timestamp': '11-Sep-2020 15:30:04',
#  'opt_timestamp': '11-Sep-2020 15:30:07',
#  'stocks': [{'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22000,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22000.00',
#     'openPrice': 190.4,
#     'highPrice': 265.4,
#     'lowPrice': 118.35,
#     'closePrice': 145.15,
#     'prevClose': 190.85,
#     'lastPrice': 125,
#     'change': -65.85,
#     'pChange': -34.50353680901232,
#     'numberOfContractsTraded': 776847,
#     'totalTurnover': 36288.47},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 161325,
#     'totalSellQuantity': 83775,
#     'bid': [{'price': 125.05, 'quantity': 50},
#      {'price': 125, 'quantity': 375},
#      {'price': 124.5, 'quantity': 75},
#      {'price': 124.45, 'quantity': 25},
#      {'price': 124, 'quantity': 50}],
#     'ask': [{'price': 131.15, 'quantity': 25},
#      {'price': 132.6, 'quantity': 25},
#      {'price': 132.95, 'quantity': 175},
#      {'price': 133, 'quantity': 500},
#      {'price': 133.05, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 125.05,
#       'bestSell': 131.15,
#       'lastPrice': 125},
#      'carry': {'bestBuy': -47373.946980150424,
#       'bestSell': -46939.34103312347,
#       'lastPrice': -47377.59625034503}},
#     'tradeInfo': {'tradedVolume': 776847,
#      'value': 36288.47,
#      'vmap': 186.85,
#      'premiumTurnover': 4308946.9654875,
#      'openInterest': 21522,
#      'changeinOpenInterest': 8797,
#      'pchangeinOpenInterest': 69.13163064833006,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 28.05,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22500,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22500.00',
#     'openPrice': 393.65,
#     'highPrice': 430,
#     'lowPrice': 237.95,
#     'closePrice': 345.6,
#     'prevClose': 379.1,
#     'lastPrice': 355,
#     'change': -24.100000000000023,
#     'pChange': -6.357161698760228,
#     'numberOfContractsTraded': 584158,
#     'totalTurnover': 46003.9},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 63700,
#     'totalSellQuantity': 105525,
#     'bid': [{'price': 351.5, 'quantity': 25},
#      {'price': 351.1, 'quantity': 150},
#      {'price': 351.05, 'quantity': 25},
#      {'price': 350, 'quantity': 175},
#      {'price': 349, 'quantity': 50}],
#     'ask': [{'price': 355, 'quantity': 2475},
#      {'price': 355.9, 'quantity': 25},
#      {'price': 356, 'quantity': 975},
#      {'price': 356.5, 'quantity': 25},
#      {'price': 356.7, 'quantity': 1000}],
#     'carryOfCost': {'price': {'bestBuy': 351.5,
#       'bestSell': 355,
#       'lastPrice': 355},
#      'carry': {'bestBuy': -37943.29548806571,
#       'bestSell': -37852.88427426536,
#       'lastPrice': -37852.88427426536}},
#     'tradeInfo': {'tradedVolume': 584158,
#      'value': 46003.9,
#      'vmap': 315.01,
#      'premiumTurnover': 3331892.652895,
#      'openInterest': 27219,
#      'changeinOpenInterest': 12601,
#      'pchangeinOpenInterest': 86.20194281023396,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 30.15,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 23000,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE23000.00',
#     'openPrice': 185,
#     'highPrice': 198.55,
#     'lowPrice': 105,
#     'closePrice': 149.65,
#     'prevClose': 181.45,
#     'lastPrice': 150.2,
#     'change': -31.25,
#     'pChange': -17.222375310002757,
#     'numberOfContractsTraded': 537411,
#     'totalTurnover': 18992.1},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 102150,
#     'totalSellQuantity': 117275,
#     'bid': [{'price': 148.2, 'quantity': 25},
#      {'price': 148, 'quantity': 350},
#      {'price': 147.7, 'quantity': 25},
#      {'price': 147.5, 'quantity': 250},
#      {'price': 147.2, 'quantity': 25}],
#     'ask': [{'price': 151.1, 'quantity': 25},
#      {'price': 151.8, 'quantity': 50},
#      {'price': 152, 'quantity': 1950},
#      {'price': 152.05, 'quantity': 75},
#      {'price': 152.2, 'quantity': 100}],
#     'carryOfCost': {'price': {'bestBuy': 148.2,
#       'bestSell': 151.1,
#       'lastPrice': 150.2},
#      'carry': {'bestBuy': -45824.0743483629,
#       'bestSell': -45647.239546060446,
#       'lastPrice': -45701.75348184196}},
#     'tradeInfo': {'tradedVolume': 537411,
#      'value': 18992.1,
#      'vmap': 141.36,
#      'premiumTurnover': 3109105.35474,
#      'openInterest': 27007,
#      'changeinOpenInterest': 10146,
#      'pchangeinOpenInterest': 60.17436688215408,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.09,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22500,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22500.00',
#     'openPrice': 390.05,
#     'highPrice': 521.25,
#     'lowPrice': 265,
#     'closePrice': 322.9,
#     'prevClose': 374.15,
#     'lastPrice': 294.2,
#     'change': -79.94999999999999,
#     'pChange': -21.368435119604435,
#     'numberOfContractsTraded': 383604,
#     'totalTurnover': 36561.3},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 62775,
#     'totalSellQuantity': 25650,
#     'bid': [{'price': 290.6, 'quantity': 175},
#      {'price': 290.2, 'quantity': 100},
#      {'price': 290.1, 'quantity': 25},
#      {'price': 290, 'quantity': 200},
#      {'price': 289.05, 'quantity': 25}],
#     'ask': [{'price': 295, 'quantity': 100},
#      {'price': 295.05, 'quantity': 50},
#      {'price': 295.1, 'quantity': 25},
#      {'price': 295.5, 'quantity': 200},
#      {'price': 295.55, 'quantity': 100}],
#     'carryOfCost': {'price': {'bestBuy': 290.6,
#       'bestSell': 295,
#       'lastPrice': 294.2},
#      'carry': {'bestBuy': -39679.43587411086,
#       'bestSell': -39542.30897662767,
#       'lastPrice': -39567.088353701576}},
#     'tradeInfo': {'tradedVolume': 383604,
#      'value': 36561.3,
#      'vmap': 381.24,
#      'premiumTurnover': 2194333.79724,
#      'openInterest': 19750,
#      'changeinOpenInterest': 8224,
#      'pchangeinOpenInterest': 71.3517265313205,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 26.33,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 23500,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE23500.00',
#     'openPrice': 74.9,
#     'highPrice': 78,
#     'lowPrice': 42.4,
#     'closePrice': 55.7,
#     'prevClose': 75.75,
#     'lastPrice': 53.85,
#     'change': -21.9,
#     'pChange': -28.910891089108908,
#     'numberOfContractsTraded': 324251,
#     'totalTurnover': 4361.99},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 183725,
#     'totalSellQuantity': 37150,
#     'bid': [{'price': 53.8, 'quantity': 25},
#      {'price': 53.75, 'quantity': 200},
#      {'price': 53.7, 'quantity': 25},
#      {'price': 53.65, 'quantity': 25},
#      {'price': 53.6, 'quantity': 25}],
#     'ask': [{'price': 54.3, 'quantity': 25},
#      {'price': 54.55, 'quantity': 25},
#      {'price': 54.6, 'quantity': 25},
#      {'price': 54.7, 'quantity': 25},
#      {'price': 54.75, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 53.8,
#       'bestSell': 54.3,
#       'lastPrice': 53.85},
#      'carry': {'bestBuy': -55070.338715322905,
#       'bestSell': -54985.92553240203,
#       'lastPrice': -55061.862170356646}},
#     'tradeInfo': {'tradedVolume': 324251,
#      'value': 4361.99,
#      'vmap': 53.81,
#      'premiumTurnover': 1909336.6115775,
#      'openInterest': 19437,
#      'changeinOpenInterest': 7740,
#      'pchangeinOpenInterest': 66.1708130289818,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.12,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22400,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22400.00',
#     'openPrice': 300,
#     'highPrice': 458.95,
#     'lowPrice': 227.5,
#     'closePrice': 278.7,
#     'prevClose': 332.2,
#     'lastPrice': 242,
#     'change': -90.19999999999999,
#     'pChange': -27.1523178807947,
#     'numberOfContractsTraded': 321862,
#     'totalTurnover': 27542.54},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 36150,
#     'totalSellQuantity': 29600,
#     'bid': [{'price': 242, 'quantity': 150},
#      {'price': 240.6, 'quantity': 225},
#      {'price': 240, 'quantity': 800},
#      {'price': 236.9, 'quantity': 750},
#      {'price': 236, 'quantity': 200}],
#     'ask': [{'price': 250, 'quantity': 25},
#      {'price': 250.1, 'quantity': 50},
#      {'price': 250.15, 'quantity': 25},
#      {'price': 250.75, 'quantity': 25},
#      {'price': 250.85, 'quantity': 200}],
#     'carryOfCost': {'price': {'bestBuy': 242,
#       'bestSell': 250,
#       'lastPrice': 242},
#      'carry': {'bestBuy': -41349.40235204876,
#       'bestSell': -41052.62822773553,
#       'lastPrice': -41349.40235204876}},
#     'tradeInfo': {'tradedVolume': 321862,
#      'value': 27542.54,
#      'vmap': 342.29,
#      'premiumTurnover': 1829969.735995,
#      'openInterest': 5271,
#      'changeinOpenInterest': 2021,
#      'pchangeinOpenInterest': 62.184615384615384,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 25.87,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22300,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22300.00',
#     'openPrice': 323.2,
#     'highPrice': 405,
#     'lowPrice': 195,
#     'closePrice': 239.15,
#     'prevClose': 289.9,
#     'lastPrice': 210,
#     'change': -79.89999999999998,
#     'pChange': -27.561228009658496,
#     'numberOfContractsTraded': 316938,
#     'totalTurnover': 23871.77},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 97025,
#     'totalSellQuantity': 34225,
#     'bid': [{'price': 210, 'quantity': 25},
#      {'price': 203.8, 'quantity': 100},
#      {'price': 202, 'quantity': 25},
#      {'price': 201.1, 'quantity': 2400},
#      {'price': 201, 'quantity': 25}],
#     'ask': [{'price': 214, 'quantity': 25},
#      {'price': 214.05, 'quantity': 25},
#      {'price': 214.1, 'quantity': 225},
#      {'price': 214.2, 'quantity': 25},
#      {'price': 214.85, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 210,
#       'bestSell': 214,
#       'lastPrice': 210},
#      'carry': {'bestBuy': -42643.60288543162,
#       'bestSell': -42471.42796615413,
#       'lastPrice': -42643.60288543162}},
#     'tradeInfo': {'tradedVolume': 316938,
#      'value': 23871.77,
#      'vmap': 301.28,
#      'premiumTurnover': 1790801.12016,
#      'openInterest': 5934,
#      'changeinOpenInterest': 3264,
#      'pchangeinOpenInterest': 122.24719101123596,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 26.76,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 21500,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE21500.00',
#     'openPrice': 93.25,
#     'highPrice': 125,
#     'lowPrice': 49.85,
#     'closePrice': 58,
#     'prevClose': 90.1,
#     'lastPrice': 51,
#     'change': -39.099999999999994,
#     'pChange': -43.39622641509433,
#     'numberOfContractsTraded': 292284,
#     'totalTurnover': 5714.88},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 155500,
#     'totalSellQuantity': 38825,
#     'bid': [{'price': 50.05, 'quantity': 25},
#      {'price': 50, 'quantity': 450},
#      {'price': 49.5, 'quantity': 25},
#      {'price': 49.1, 'quantity': 100},
#      {'price': 49, 'quantity': 75}],
#     'ask': [{'price': 52.2, 'quantity': 1775},
#      {'price': 52.35, 'quantity': 200},
#      {'price': 52.4, 'quantity': 1050},
#      {'price': 52.65, 'quantity': 25},
#      {'price': 53, 'quantity': 325}],
#     'carryOfCost': {'price': {'bestBuy': 50.05,
#       'bestSell': 52.2,
#       'lastPrice': 51},
#      'carry': {'bestBuy': -55729.628738157306,
#       'bestSell': -55345.83133737012,
#       'lastPrice': -55558.05020461905}},
#     'tradeInfo': {'tradedVolume': 292284,
#      'value': 5714.88,
#      'vmap': 78.21,
#      'premiumTurnover': 1576741.38291,
#      'openInterest': 16530,
#      'changeinOpenInterest': 7728,
#      'pchangeinOpenInterest': 87.7982276755283,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 30.68,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22200,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22200.00',
#     'openPrice': 240,
#     'highPrice': 352.55,
#     'lowPrice': 166,
#     'closePrice': 203.05,
#     'prevClose': 252.25,
#     'lastPrice': 181.5,
#     'change': -70.75,
#     'pChange': -28.047571853320118,
#     'numberOfContractsTraded': 290457,
#     'totalTurnover': 18729.39},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 113675,
#     'totalSellQuantity': 34300,
#     'bid': [{'price': 175.95, 'quantity': 25},
#      {'price': 171.15, 'quantity': 100},
#      {'price': 168, 'quantity': 525},
#      {'price': 167.6, 'quantity': 750},
#      {'price': 166.45, 'quantity': 750}],
#     'ask': [{'price': 181.55, 'quantity': 25},
#      {'price': 183.05, 'quantity': 25},
#      {'price': 183.9, 'quantity': 125},
#      {'price': 184, 'quantity': 75},
#      {'price': 184.95, 'quantity': 50}],
#     'carryOfCost': {'price': {'bestBuy': 175.95,
#       'bestSell': 181.55,
#       'lastPrice': 181.5},
#      'carry': {'bestBuy': -44257.88534634923,
#       'bestSell': -43971.98783525288,
#       'lastPrice': -43974.50126317126}},
#     'tradeInfo': {'tradedVolume': 290457,
#      'value': 18729.39,
#      'vmap': 257.93,
#      'premiumTurnover': 1630765.7435025,
#      'openInterest': 6568,
#      'changeinOpenInterest': 4234,
#      'pchangeinOpenInterest': 181.40531276778063,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 27.57,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22700,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22700.00',
#     'openPrice': 250.05,
#     'highPrice': 322.15,
#     'lowPrice': 175.25,
#     'closePrice': 251.7,
#     'prevClose': 289.3,
#     'lastPrice': 257.65,
#     'change': -31.650000000000034,
#     'pChange': -10.94020048392673,
#     'numberOfContractsTraded': 289867,
#     'totalTurnover': 16842.72},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 79275,
#     'totalSellQuantity': 42725,
#     'bid': [{'price': 256, 'quantity': 25},
#      {'price': 254.85, 'quantity': 200},
#      {'price': 254.8, 'quantity': 25},
#      {'price': 254.4, 'quantity': 25},
#      {'price': 254.3, 'quantity': 25}],
#     'ask': [{'price': 258.5, 'quantity': 50},
#      {'price': 259, 'quantity': 1700},
#      {'price': 259.1, 'quantity': 50},
#      {'price': 259.7, 'quantity': 100},
#      {'price': 260, 'quantity': 1150}],
#     'carryOfCost': {'price': {'bestBuy': 256,
#       'bestSell': 258.5,
#       'lastPrice': 257.65},
#      'carry': {'bestBuy': -40836.21492235251,
#       'bestSell': -40747.535895948604,
#       'lastPrice': -40777.590170913645}},
#     'tradeInfo': {'tradedVolume': 289867,
#      'value': 16842.72,
#      'vmap': 232.42,
#      'premiumTurnover': 1661837.947035,
#      'openInterest': 8699,
#      'changeinOpenInterest': 2737,
#      'pchangeinOpenInterest': 45.90741361959074,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.56,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Futures',
#     'expiryDate': '24-Sep-2020',
#     'optionType': '-',
#     'strikePrice': 0,
#     'identifier': 'FUTIDXBANKNIFTY24-09-2020XX0.00',
#     'openPrice': 22450.55,
#     'highPrice': 22676,
#     'lowPrice': 22226,
#     'closePrice': 22538.95,
#     'prevClose': 22506.6,
#     'lastPrice': 22575,
#     'change': 68.40000000000146,
#     'pChange': 0.30391085281651364,
#     'numberOfContractsTraded': 285392,
#     'totalTurnover': 1600657.42},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 0,
#    'marketDeptOrderBook': {'totalBuyQuantity': 117175,
#     'totalSellQuantity': 145925,
#     'bid': [{'price': 22574.5, 'quantity': 50},
#      {'price': 22574, 'quantity': 50},
#      {'price': 22573.5, 'quantity': 50},
#      {'price': 22573, 'quantity': 50},
#      {'price': 22572.5, 'quantity': 50}],
#     'ask': [{'price': 22579.95, 'quantity': 50},
#      {'price': 22580, 'quantity': 75},
#      {'price': 22583.1, 'quantity': 25},
#      {'price': 22583.55, 'quantity': 125},
#      {'price': 22583.65, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 22574.5,
#       'bestSell': 22579.95,
#       'lastPrice': 22575},
#      'carry': {'bestBuy': 13.926906286608654,
#       'bestSell': 14.727894494720905,
#       'lastPrice': 14.000399499563585}},
#     'tradeInfo': {'tradedVolume': 285392,
#      'value': 1600657.42,
#      'vmap': 22434.51,
#      'premiumTurnover': 1600657.41948,
#      'openInterest': 59879,
#      'changeinOpenInterest': 3276,
#      'pchangeinOpenInterest': 5.78767909828101,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 22538.95,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 0,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22600,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22600.00',
#     'openPrice': 331.95,
#     'highPrice': 374.7,
#     'lowPrice': 205,
#     'closePrice': 295.75,
#     'prevClose': 331.95,
#     'lastPrice': 302,
#     'change': -29.94999999999999,
#     'pChange': -9.022443139026958,
#     'numberOfContractsTraded': 276453,
#     'totalTurnover': 19098.76},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 46350,
#     'totalSellQuantity': 39925,
#     'bid': [{'price': 302, 'quantity': 525},
#      {'price': 299, 'quantity': 175},
#      {'price': 298.9, 'quantity': 200},
#      {'price': 298.7, 'quantity': 25},
#      {'price': 298.5, 'quantity': 50}],
#     'ask': [{'price': 302.55, 'quantity': 50},
#      {'price': 303, 'quantity': 350},
#      {'price': 303.3, 'quantity': 75},
#      {'price': 304, 'quantity': 25},
#      {'price': 304.8, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 302,
#       'bestSell': 302.55,
#       'lastPrice': 302},
#      'carry': {'bestBuy': -39328.31256968284,
#       'bestSell': -39311.70930648001,
#       'lastPrice': -39328.31256968284}},
#     'tradeInfo': {'tradedVolume': 276453,
#      'value': 19098.76,
#      'vmap': 276.34,
#      'premiumTurnover': 1581058.205505,
#      'openInterest': 10738,
#      'changeinOpenInterest': 6706,
#      'pchangeinOpenInterest': 166.31944444444446,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.68,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22800,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22800.00',
#     'openPrice': 207.75,
#     'highPrice': 275.9,
#     'lowPrice': 148.45,
#     'closePrice': 213.4,
#     'prevClose': 247.25,
#     'lastPrice': 216.8,
#     'change': -30.44999999999999,
#     'pChange': -12.315470171890794,
#     'numberOfContractsTraded': 262219,
#     'totalTurnover': 13038.18},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 86150,
#     'totalSellQuantity': 31750,
#     'bid': [{'price': 214, 'quantity': 25},
#      {'price': 213.55, 'quantity': 25},
#      {'price': 212, 'quantity': 625},
#      {'price': 211, 'quantity': 25},
#      {'price': 210.05, 'quantity': 25}],
#     'ask': [{'price': 217, 'quantity': 150},
#      {'price': 218, 'quantity': 650},
#      {'price': 218.5, 'quantity': 75},
#      {'price': 219, 'quantity': 50},
#      {'price': 219.9, 'quantity': 150}],
#     'carryOfCost': {'price': {'bestBuy': 214,
#       'bestSell': 217,
#       'lastPrice': 216.8},
#      'carry': {'bestBuy': -42471.42796615413,
#       'bestSell': -42344.39575217183,
#       'lastPrice': -42352.80976844342}},
#     'tradeInfo': {'tradedVolume': 262219,
#      'value': 13038.18,
#      'vmap': 198.89,
#      'premiumTurnover': 1507686.4842275,
#      'openInterest': 8129,
#      'changeinOpenInterest': 4472,
#      'pchangeinOpenInterest': 122.28602679792179,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.35,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22400,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22400.00',
#     'openPrice': 376.65,
#     'highPrice': 493.25,
#     'lowPrice': 273.05,
#     'closePrice': 399.85,
#     'prevClose': 430.6,
#     'lastPrice': 406,
#     'change': -24.600000000000023,
#     'pChange': -5.712958662331635,
#     'numberOfContractsTraded': 257683,
#     'totalTurnover': 23076.8},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 35100,
#     'totalSellQuantity': 17325,
#     'bid': [{'price': 406.25, 'quantity': 25},
#      {'price': 405.85, 'quantity': 25},
#      {'price': 405.75, 'quantity': 25},
#      {'price': 405.05, 'quantity': 200},
#      {'price': 405, 'quantity': 25}],
#     'ask': [{'price': 412, 'quantity': 25},
#      {'price': 412.45, 'quantity': 50},
#      {'price': 415, 'quantity': 150},
#      {'price': 418, 'quantity': 25},
#      {'price': 418.3, 'quantity': 50}],
#     'carryOfCost': {'price': {'bestBuy': 406.25,
#       'bestSell': 412,
#       'lastPrice': 406},
#      'carry': {'bestBuy': -36622.3694087275,
#       'bestSell': -36494.121040414095,
#       'lastPrice': -36627.98652186271}},
#     'tradeInfo': {'tradedVolume': 257683,
#      'value': 23076.8,
#      'vmap': 358.22,
#      'premiumTurnover': 1466101.601065,
#      'openInterest': 5594,
#      'changeinOpenInterest': 2731,
#      'pchangeinOpenInterest': 95.38945162417045,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 30.04,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22100,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22100.00',
#     'openPrice': 200.25,
#     'highPrice': 310,
#     'lowPrice': 140.55,
#     'closePrice': 172.4,
#     'prevClose': 217.4,
#     'lastPrice': 154.75,
#     'change': -62.650000000000006,
#     'pChange': -28.817847286108556,
#     'numberOfContractsTraded': 203301,
#     'totalTurnover': 11199.85},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 146000,
#     'totalSellQuantity': 22725,
#     'bid': [{'price': 150, 'quantity': 125},
#      {'price': 145.6, 'quantity': 25},
#      {'price': 145, 'quantity': 25},
#      {'price': 144, 'quantity': 25},
#      {'price': 140.5, 'quantity': 275}],
#     'ask': [{'price': 154.75, 'quantity': 175},
#      {'price': 154.8, 'quantity': 50},
#      {'price': 154.85, 'quantity': 25},
#      {'price': 155, 'quantity': 825},
#      {'price': 155.05, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 150,
#       'bestSell': 154.75,
#       'lastPrice': 154.75},
#      'carry': {'bestBuy': -45713.91204460019,
#       'bestSell': -45429.434535200584,
#       'lastPrice': -45429.434535200584}},
#     'tradeInfo': {'tradedVolume': 203301,
#      'value': 11199.85,
#      'vmap': 220.36,
#      'premiumTurnover': 1134437.87709,
#      'openInterest': 5636,
#      'changeinOpenInterest': 4065,
#      'pchangeinOpenInterest': 258.75238701464036,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 28.17,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 21000,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE21000.00',
#     'openPrice': 44,
#     'highPrice': 45.75,
#     'lowPrice': 18.5,
#     'closePrice': 22.85,
#     'prevClose': 42.3,
#     'lastPrice': 19.5,
#     'change': -22.799999999999997,
#     'pChange': -53.90070921985816,
#     'numberOfContractsTraded': 195511,
#     'totalTurnover': 1539.65},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 249125,
#     'totalSellQuantity': 47325,
#     'bid': [{'price': 19.5, 'quantity': 1325},
#      {'price': 19.35, 'quantity': 150},
#      {'price': 19.1, 'quantity': 1000},
#      {'price': 19, 'quantity': 100},
#      {'price': 18.95, 'quantity': 25}],
#     'ask': [{'price': 20.15, 'quantity': 50},
#      {'price': 20.35, 'quantity': 50},
#      {'price': 20.5, 'quantity': 1025},
#      {'price': 20.6, 'quantity': 50},
#      {'price': 20.65, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 19.5,
#       'bestSell': 20.15,
#       'lastPrice': 19.5},
#      'carry': {'bestBuy': -64330.927104905,
#       'bestSell': -64031.71997164521,
#       'lastPrice': -64330.927104905}},
#     'tradeInfo': {'tradedVolume': 195511,
#      'value': 1539.65,
#      'vmap': 31.5,
#      'premiumTurnover': 1027972.399125,
#      'openInterest': 26593,
#      'changeinOpenInterest': 5344,
#      'pchangeinOpenInterest': 25.149418796178644,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 33.17,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 21800,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE21800.00',
#     'openPrice': 110,
#     'highPrice': 196.55,
#     'lowPrice': 85.2,
#     'closePrice': 101.2,
#     'prevClose': 141.4,
#     'lastPrice': 94.9,
#     'change': -46.5,
#     'pChange': -32.88543140028288,
#     'numberOfContractsTraded': 185757,
#     'totalTurnover': 6106.3},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 138775,
#     'totalSellQuantity': 22550,
#     'bid': [{'price': 90, 'quantity': 50},
#      {'price': 89, 'quantity': 1125},
#      {'price': 88, 'quantity': 25},
#      {'price': 87, 'quantity': 25},
#      {'price': 86, 'quantity': 100}],
#     'ask': [{'price': 93.5, 'quantity': 50},
#      {'price': 94.85, 'quantity': 75},
#      {'price': 94.9, 'quantity': 175},
#      {'price': 94.95, 'quantity': 175},
#      {'price': 95, 'quantity': 750}],
#     'carryOfCost': {'price': {'bestBuy': 90,
#       'bestSell': 93.5,
#       'lastPrice': 94.9},
#      'carry': {'bestBuy': -50375.195861464854,
#       'bestSell': -50027.060997039924,
#       'lastPrice': -49891.4427894836}},
#     'tradeInfo': {'tradedVolume': 185757,
#      'value': 6106.3,
#      'vmap': 131.49,
#      'premiumTurnover': 1018481.9469825,
#      'openInterest': 6141,
#      'changeinOpenInterest': 3278,
#      'pchangeinOpenInterest': 114.4952846664338,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.98,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 21900,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE21900.00',
#     'openPrice': 177.65,
#     'highPrice': 230,
#     'lowPrice': 100,
#     'closePrice': 121.2,
#     'prevClose': 163.35,
#     'lastPrice': 110.45,
#     'change': -52.89999999999999,
#     'pChange': -32.38445056626875,
#     'numberOfContractsTraded': 184903,
#     'totalTurnover': 7481.18},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 158200,
#     'totalSellQuantity': 32625,
#     'bid': [{'price': 107, 'quantity': 100},
#      {'price': 105.1, 'quantity': 25},
#      {'price': 105, 'quantity': 50},
#      {'price': 104.9, 'quantity': 25},
#      {'price': 102, 'quantity': 50}],
#     'ask': [{'price': 110.3, 'quantity': 25},
#      {'price': 110.9, 'quantity': 25},
#      {'price': 110.95, 'quantity': 200},
#      {'price': 111, 'quantity': 400},
#      {'price': 112.35, 'quantity': 50}],
#     'carryOfCost': {'price': {'bestBuy': 107,
#       'bestSell': 110.3,
#       'lastPrice': 110.45},
#      'carry': {'bestBuy': -48796.39598876363,
#       'bestSell': -48519.223276110984,
#       'lastPrice': -48506.822368200126}},
#     'tradeInfo': {'tradedVolume': 184903,
#      'value': 7481.18,
#      'vmap': 161.84,
#      'premiumTurnover': 1019825.10038,
#      'openInterest': 4066,
#      'changeinOpenInterest': 2082,
#      'pchangeinOpenInterest': 104.93951612903226,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.21,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 24000,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE24000.00',
#     'openPrice': 15.25,
#     'highPrice': 29.6,
#     'lowPrice': 15.25,
#     'closePrice': 23.4,
#     'prevClose': 30.35,
#     'lastPrice': 22.25,
#     'change': -8.100000000000001,
#     'pChange': -26.688632619439872,
#     'numberOfContractsTraded': 158389,
#     'totalTurnover': 883.41},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 283050,
#     'totalSellQuantity': 43600,
#     'bid': [{'price': 22.25, 'quantity': 200},
#      {'price': 21.9, 'quantity': 25},
#      {'price': 21.55, 'quantity': 100},
#      {'price': 21.5, 'quantity': 125},
#      {'price': 21.25, 'quantity': 1700}],
#     'ask': [{'price': 22.4, 'quantity': 25},
#      {'price': 23, 'quantity': 375},
#      {'price': 23.5, 'quantity': 50},
#      {'price': 23.75, 'quantity': 50},
#      {'price': 24, 'quantity': 675}],
#     'carryOfCost': {'price': {'bestBuy': 22.25,
#       'bestSell': 22.4,
#       'lastPrice': 22.25},
#      'carry': {'bestBuy': -63127.08827464175,
#       'bestSell': -63065.777853621956,
#       'lastPrice': -63127.08827464175}},
#     'tradeInfo': {'tradedVolume': 158389,
#      'value': 883.41,
#      'vmap': 22.31,
#      'premiumTurnover': 951217.4146475,
#      'openInterest': 18393,
#      'changeinOpenInterest': 7495,
#      'pchangeinOpenInterest': 68.77408698843824,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 31.32,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22900,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22900.00',
#     'openPrice': 171.15,
#     'highPrice': 236,
#     'lowPrice': 125.65,
#     'closePrice': 179.35,
#     'prevClose': 213.7,
#     'lastPrice': 178.5,
#     'change': -35.19999999999999,
#     'pChange': -16.471689284043048,
#     'numberOfContractsTraded': 155905,
#     'totalTurnover': 6592.05},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 98875,
#     'totalSellQuantity': 34975,
#     'bid': [{'price': 178.5, 'quantity': 250},
#      {'price': 178.35, 'quantity': 25},
#      {'price': 178.05, 'quantity': 25},
#      {'price': 172.55, 'quantity': 500},
#      {'price': 172.1, 'quantity': 500}],
#     'ask': [{'price': 181, 'quantity': 475},
#      {'price': 182, 'quantity': 325},
#      {'price': 183, 'quantity': 575},
#      {'price': 184, 'quantity': 250},
#      {'price': 184.7, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 178.5,
#       'bestSell': 181,
#       'lastPrice': 178.5},
#      'carry': {'bestBuy': 0,
#       'bestSell': -43999.67369292786,
#       'lastPrice': -44126.58811709882}},
#     'tradeInfo': {'tradedVolume': 155905,
#      'value': 6592.05,
#      'vmap': 169.13,
#      'premiumTurnover': 899148.1781625,
#      'openInterest': 4175,
#      'changeinOpenInterest': 1628,
#      'pchangeinOpenInterest': 63.918335296427166,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 28.95,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 22300,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE22300.00',
#     'openPrice': 442.45,
#     'highPrice': 561,
#     'lowPrice': 306.7,
#     'closePrice': 459.35,
#     'prevClose': 493.7,
#     'lastPrice': 478.85,
#     'change': -14.849999999999966,
#     'pChange': -3.0078995341300314,
#     'numberOfContractsTraded': 148970,
#     'totalTurnover': 15001.28},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 26550,
#     'totalSellQuantity': 16125,
#     'bid': [{'price': 465, 'quantity': 25},
#      {'price': 461.85, 'quantity': 200},
#      {'price': 461.8, 'quantity': 50},
#      {'price': 461.7, 'quantity': 125},
#      {'price': 461.3, 'quantity': 50}],
#     'ask': [{'price': 479, 'quantity': 100},
#      {'price': 480, 'quantity': 550},
#      {'price': 480.5, 'quantity': 100},
#      {'price': 482, 'quantity': 25},
#      {'price': 484, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 465,
#       'bestSell': 479,
#       'lastPrice': 478.85},
#      'carry': {'bestBuy': -35389.8677772439,
#       'bestSell': -35119.19115185392,
#       'lastPrice': -35122.04911502392}},
#     'tradeInfo': {'tradedVolume': 148970,
#      'value': 15001.28,
#      'vmap': 402.8,
#      'premiumTurnover': 845509.029,
#      'openInterest': 3270,
#      'changeinOpenInterest': 1436,
#      'pchangeinOpenInterest': 78.29880043620501,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 31.48,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 23200,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE23200.00',
#     'openPrice': 138.5,
#     'highPrice': 139.35,
#     'lowPrice': 73.6,
#     'closePrice': 102.05,
#     'prevClose': 130.3,
#     'lastPrice': 102.7,
#     'change': -27.60000000000001,
#     'pChange': -21.181887950882583,
#     'numberOfContractsTraded': 138522,
#     'totalTurnover': 3356.73},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 76925,
#     'totalSellQuantity': 25150,
#     'bid': [{'price': 100.05, 'quantity': 625},
#      {'price': 100, 'quantity': 150},
#      {'price': 99.05, 'quantity': 25},
#      {'price': 99, 'quantity': 100},
#      {'price': 97.85, 'quantity': 25}],
#     'ask': [{'price': 102.7, 'quantity': 25},
#      {'price': 103, 'quantity': 875},
#      {'price': 103.2, 'quantity': 100},
#      {'price': 103.5, 'quantity': 25},
#      {'price': 103.9, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 100.05,
#       'bestSell': 102.7,
#       'lastPrice': 102.7},
#      'carry': {'bestBuy': -49409.21979633212,
#       'bestSell': -49170.6735362011,
#       'lastPrice': -49170.6735362011}},
#     'tradeInfo': {'tradedVolume': 138522,
#      'value': 3356.73,
#      'vmap': 96.93,
#      'premiumTurnover': 806784.334365,
#      'openInterest': 6772,
#      'changeinOpenInterest': 3900,
#      'pchangeinOpenInterest': 135.79387186629526,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.16,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 22600,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE22600.00',
#     'openPrice': 411.05,
#     'highPrice': 588.9,
#     'lowPrice': 306.35,
#     'closePrice': 374.5,
#     'prevClose': 423.25,
#     'lastPrice': 330.9,
#     'change': -92.35000000000002,
#     'pChange': -21.81925575900768,
#     'numberOfContractsTraded': 130886,
#     'totalTurnover': 13832.69},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 40775,
#     'totalSellQuantity': 18850,
#     'bid': [{'price': 330.9, 'quantity': 25},
#      {'price': 330.85, 'quantity': 200},
#      {'price': 330.1, 'quantity': 225},
#      {'price': 325.3, 'quantity': 100},
#      {'price': 325.15, 'quantity': 125}],
#     'ask': [{'price': 339.55, 'quantity': 25},
#      {'price': 339.6, 'quantity': 50},
#      {'price': 339.75, 'quantity': 25},
#      {'price': 339.85, 'quantity': 50},
#      {'price': 339.9, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 330.9,
#       'bestSell': 339.55,
#       'lastPrice': 330.9},
#      'carry': {'bestBuy': -1833.0660067625943,
#       'bestSell': -38258.915547745346,
#       'lastPrice': -38494.38614201448}},
#     'tradeInfo': {'tradedVolume': 130886,
#      'value': 13832.69,
#      'vmap': 422.74,
#      'premiumTurnover': 753338.58691,
#      'openInterest': 2754,
#      'changeinOpenInterest': 1642,
#      'pchangeinOpenInterest': 147.66187050359713,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 24.96,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 21700,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE21700.00',
#     'openPrice': 148.8,
#     'highPrice': 164.9,
#     'lowPrice': 72.25,
#     'closePrice': 85.4,
#     'prevClose': 121.4,
#     'lastPrice': 75.65,
#     'change': -45.75,
#     'pChange': -37.68533772652389,
#     'numberOfContractsTraded': 130754,
#     'totalTurnover': 3607.18},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 179775,
#     'totalSellQuantity': 14775,
#     'bid': [{'price': 75.65, 'quantity': 350},
#      {'price': 75, 'quantity': 25},
#      {'price': 74.4, 'quantity': 200},
#      {'price': 73.1, 'quantity': 50},
#      {'price': 73, 'quantity': 25}],
#     'ask': [{'price': 77, 'quantity': 100},
#      {'price': 77.95, 'quantity': 50},
#      {'price': 78, 'quantity': 50},
#      {'price': 79, 'quantity': 75},
#      {'price': 80, 'quantity': 250}],
#     'carryOfCost': {'price': {'bestBuy': 75.65,
#       'bestSell': 77,
#       'lastPrice': 75.65},
#      'carry': {'bestBuy': -51960.137461089944,
#       'bestSell': -51798.73462881366,
#       'lastPrice': -51960.137461089944}},
#     'tradeInfo': {'tradedVolume': 130754,
#      'value': 3607.18,
#      'vmap': 110.35,
#      'premiumTurnover': 712947.625975,
#      'openInterest': 5004,
#      'changeinOpenInterest': 3177,
#      'pchangeinOpenInterest': 173.89162561576356,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.93,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 23100,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE23100.00',
#     'openPrice': 189.3,
#     'highPrice': 189.3,
#     'lowPrice': 88.1,
#     'closePrice': 123.7,
#     'prevClose': 155.45,
#     'lastPrice': 120.15,
#     'change': -35.29999999999998,
#     'pChange': -22.708266323576705,
#     'numberOfContractsTraded': 121374,
#     'totalTurnover': 3541.39},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 75825,
#     'totalSellQuantity': 16875,
#     'bid': [{'price': 120.45, 'quantity': 25},
#      {'price': 120.3, 'quantity': 100},
#      {'price': 120, 'quantity': 75},
#      {'price': 118, 'quantity': 100},
#      {'price': 117, 'quantity': 25}],
#     'ask': [{'price': 125, 'quantity': 100},
#      {'price': 126, 'quantity': 75},
#      {'price': 127.9, 'quantity': 25},
#      {'price': 128, 'quantity': 25},
#      {'price': 128.6, 'quantity': 50}],
#     'carryOfCost': {'price': {'bestBuy': 120.45,
#       'bestSell': 125,
#       'lastPrice': 120.15},
#      'carry': {'bestBuy': -47715.94220054799,
#       'bestSell': -47377.59625034503,
#       'lastPrice': -47738.697823313414}},
#     'tradeInfo': {'tradedVolume': 121374,
#      'value': 3541.39,
#      'vmap': 116.71,
#      'premiumTurnover': 704476.239885,
#      'openInterest': 5053,
#      'changeinOpenInterest': 2856,
#      'pchangeinOpenInterest': 129.9954483386436,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 28.63,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 23300,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE23300.00',
#     'openPrice': 116.5,
#     'highPrice': 128.8,
#     'lowPrice': 61.6,
#     'closePrice': 83.9,
#     'prevClose': 110.85,
#     'lastPrice': 81.55,
#     'change': -29.299999999999997,
#     'pChange': -26.432115471357687,
#     'numberOfContractsTraded': 90040,
#     'totalTurnover': 1820.16},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 84675,
#     'totalSellQuantity': 22000,
#     'bid': [{'price': 81, 'quantity': 25},
#      {'price': 80.05, 'quantity': 350},
#      {'price': 80, 'quantity': 250},
#      {'price': 79.8, 'quantity': 25},
#      {'price': 79, 'quantity': 250}],
#     'ask': [{'price': 83, 'quantity': 25},
#      {'price': 83.8, 'quantity': 75},
#      {'price': 84, 'quantity': 75},
#      {'price': 84.1, 'quantity': 25},
#      {'price': 84.75, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 81,
#       'bestSell': 83,
#       'lastPrice': 81.55},
#      'carry': {'bestBuy': -51336.61056684252,
#       'bestSell': -51114.03855708457,
#       'lastPrice': -51274.86010049194}},
#     'tradeInfo': {'tradedVolume': 90040,
#      'value': 1820.16,
#      'vmap': 80.86,
#      'premiumTurnover': 526303.1586,
#      'openInterest': 6123,
#      'changeinOpenInterest': 1937,
#      'pchangeinOpenInterest': 46.27329192546584,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 28.89,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Call',
#     'strikePrice': 23400,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020CE23400.00',
#     'openPrice': 100.25,
#     'highPrice': 100.25,
#     'lowPrice': 51.25,
#     'closePrice': 68.65,
#     'prevClose': 91.95,
#     'lastPrice': 67.95,
#     'change': -24,
#     'pChange': -26.101141924959215,
#     'numberOfContractsTraded': 89693,
#     'totalTurnover': 1515.59},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 142175,
#     'totalSellQuantity': 30200,
#     'bid': [{'price': 65.3, 'quantity': 25},
#      {'price': 65.15, 'quantity': 200},
#      {'price': 65.1, 'quantity': 150},
#      {'price': 65, 'quantity': 25},
#      {'price': 64, 'quantity': 25}],
#     'ask': [{'price': 67.95, 'quantity': 100},
#      {'price': 68, 'quantity': 425},
#      {'price': 68.5, 'quantity': 200},
#      {'price': 69, 'quantity': 100},
#      {'price': 69.05, 'quantity': 25}],
#     'carryOfCost': {'price': {'bestBuy': 65.3,
#       'bestSell': 67.95,
#       'lastPrice': 67.95},
#      'carry': {'bestBuy': -53302.65677215176,
#       'bestSell': -52939.663320279506,
#       'lastPrice': -52939.663320279506}},
#     'tradeInfo': {'tradedVolume': 89693,
#      'value': 1515.59,
#      'vmap': 67.59,
#      'premiumTurnover': 526219.6374675,
#      'openInterest': 4559,
#      'changeinOpenInterest': 2842,
#      'pchangeinOpenInterest': 165.52125800815375,
#      'marketLot': 25},
#     'otherInfo': {'settlementPrice': 0,
#      'dailyvolatility': 2.37,
#      'annualisedVolatility': 45.3,
#      'impliedVolatility': 29.22,
#      'clientWisePositionLimits': 0,
#      'marketWidePositionLimits': 0}}},
#   {'metadata': {'instrumentType': 'Index Options',
#     'expiryDate': '17-Sep-2020',
#     'optionType': 'Put',
#     'strikePrice': 21600,
#     'identifier': 'OPTIDXBANKNIFTY17-09-2020PE21600.00',
#     'openPrice': 102.95,
#     'highPrice': 141.5,
#     'lowPrice': 59.85,
#     'closePrice': 69.65,
#     'prevClose': 103.85,
#     'lastPrice': 60.7,
#     'change': -43.14999999999999,
#     'pChange': -41.55031295137216,
#     'numberOfContractsTraded': 89362,
#     'totalTurnover': 2070.29},
#    'underlyingValue': 22479.95,
#    'volumeFreezeQuantity': 2501,
#    'marketDeptOrderBook': {'totalBuyQuantity': 172650,
#     'totalSellQuantity': 28250,
#     'bid': [{'price': 62, 'quantity': 25},
#      {'price': 60.05, 'quantity': 50},
#      {'price': 59, 'quantity': 25},
#      {'price': 58.2, 'quantity': 175},
# ...
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '17-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '24-Sep-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '01-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '08-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '15-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '22-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   '29-Oct-2020',
#   ...]}

# %%
nse_quote_ltp("BANKNIFTY","latest","Fut")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 127124
# 22575

# %%
nse_quote_meta("BANKNIFTY","latest","Fut")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 127124
# {'instrumentType': 'Index Futures',
#  'expiryDate': '24-Sep-2020',
#  'optionType': '-',
#  'strikePrice': 0,
#  'identifier': 'FUTIDXBANKNIFTY24-09-2020XX0.00',
#  'openPrice': 22450.55,
#  'highPrice': 22676,
#  'lowPrice': 22226,
#  'closePrice': 22538.95,
#  'prevClose': 22506.6,
#  'lastPrice': 22575,
#  'change': 68.40000000000146,
#  'pChange': 0.30391085281651364,
#  'numberOfContractsTraded': 285392,
#  'totalTurnover': 1600657.42}

# %%
banknifty_info=nse_quote_meta("BANKNIFTY","latest","Fut")
range_high = banknifty_info['highPrice']
range_low = banknifty_info['lowPrice']
opening_range = range_high-range_low

golden_number = (float(previous_day_high)-float(previous_day_low)+opening_range)*.618

previous_day_close = banknifty_info['prevClose']

# %%
from nsepython import * 

#Getting All the Necessary Variables

historical_data = nsefetch('https://www.nseindia.com/api/historical/fo/derivatives?&expiryDate=24-SEP-2020&instrumentType=FUTIDX&symbol=BANKNIFTY')
historical_data = pd.DataFrame(historical_data['data'])
previous_day_high = historical_data['FH_TRADE_HIGH_PRICE'].iloc[0]
previous_day_low = historical_data['FH_TRADE_LOW_PRICE'].iloc[0]

banknifty_info=nse_quote_meta("BANKNIFTY","latest","Fut")
range_high = banknifty_info['highPrice']
range_low = banknifty_info['lowPrice']
opening_range = range_high-range_low

golden_number = (float(previous_day_high)-float(previous_day_low)+opening_range)*.618

previous_day_close = banknifty_info['prevClose']
buy_above = int(previous_day_close+golden_number)
sell_below = int(previous_day_close-golden_number)

print("Buy BankNIFTY Above: "+str(buy_above)+".")
print("Sell BankNIFTY Below: "+str(sell_below)+".")

#Entering the Trade

while True: 
    bn_ltp = nse_quote_ltp("BANKNIFTY","latest","Fut")
    print("Current Value of BankNIFTY: " + str(bn_ltp))
    
    who_triggered = "NONE"
    
    #Amit's Test
    bn_ltp = 21949
    
    if(bn_ltp>buy_above):
        print("Buy Order executed at: " +str(bn_ltp)+". Entry Time is "+ str(run_time)+".")
        who_triggered = "BUY"
        stop_loss = bn_ltp*(.995)
        target = bn_ltp*(1.02)
    
    if(bn_ltp<sell_below):
        print("Sell Order executed at: " +str(bn_ltp)+". Entry Time is "+ str(run_time)+".")
        who_triggered = "SELL"
        stop_loss = bn_ltp*(1.005)
        target = bn_ltp*(.98)
    
    if(who_triggered != "NONE"):
        entry_price = run_time
        entry_price = bn_ltp
        print("Stop Loss is: " + str(stop_loss)+".")
        print("Target is: " + str(target)+".")
        break        
        
    time.sleep(10)

#Managing the Trade

while True:
    bn_ltp = nse_quote_ltp("BANKNIFTY","latest","Fut")
    print("Current Value of BankNIFTY: " + str(bn_ltp))
    
    exit_time = run_time
    exit_price = bn_ltp
        
    if(who_triggered == "BUY"):
        
        if(bn_ltp>target):
            print("Target hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Profit: "+str(abs(entry_price-exit_price))+" points.")
            break
            
        if(bn_ltp<stop_loss):
            print("Stop Loss hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Loss: "+str(abs(entry_price-exit_price))+" points.")
            break
    
    if(who_triggered == "SELL"):
        
        if(bn_ltp<target):
            print("Target hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Profit: "+str(abs(entry_price-exit_price))+" points.")
            break
            
        if(bn_ltp>stop_loss):
            print("Stop Loss hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Loss: "+str(abs(entry_price-exit_price))+" points.")
            break
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/historical/fo/derivatives?&expiryDate=24-SEP-2020&instrumentType=FUTIDX&symbol=BANKNIFTY HTTP/1.1" 200 2107
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 127284
# Buy BankNIFTY Above: 23062.
# Sell BankNIFTY Below: 21950.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/equity-stockIndices?index=SECURITIES%20IN%20F%26O HTTP/1.1" 200 21240
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# Current Value of BankNIFTY: 22575
# Sell Order executed at: 21949. Entry Time is 2020-09-14 02:23:29.293291.
# Stop Loss is: 22058.745.
# Target is: 21510.02.
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=BANKNIFTY HTTP/1.1" 200 127284
# Current Value of BankNIFTY: 22575
# Stop Loss hit at: 22575. Exit Time is 2020-09-14 02:23:29.293291.
# Net Loss: 626 points.

# %%
from nsepython import * 

#The Golden Ratio BankNIFTY Strategy
##Scrip = BANKNIFTY

## Golden Number = ((Previous Day High - Previous Day Low) + Opening Range of Today's First 10m))*61.8%

### Buy Above = (Previous Day Close + Golden Number)
### Sell Below = (Previous Day Close - Goldern Number)

#### Stop Loss at 0.5% Target at 2%


#Getting All the Necessary Variables

historical_data = nsefetch('https://www.nseindia.com/api/historical/fo/derivatives?&expiryDate=24-SEP-2020&instrumentType=FUTIDX&symbol=BANKNIFTY')
historical_data = pd.DataFrame(historical_data['data'])
previous_day_high = historical_data['FH_TRADE_HIGH_PRICE'].iloc[0]
previous_day_low = historical_data['FH_TRADE_LOW_PRICE'].iloc[0]

banknifty_info=nse_quote_meta("BANKNIFTY","latest","Fut")
range_high = banknifty_info['highPrice']
range_low = banknifty_info['lowPrice']
opening_range = range_high-range_low

golden_number = (float(previous_day_high)-float(previous_day_low)+opening_range)*.618

previous_day_close = banknifty_info['prevClose']
buy_above = int(previous_day_close+golden_number)
sell_below = int(previous_day_close-golden_number)

print("Buy BankNIFTY Above: "+str(buy_above)+".")
print("Sell BankNIFTY Below: "+str(sell_below)+".")

#Entering the Trade

while True: 
    
    bn_ltp = nse_quote_ltp("BANKNIFTY","latest","Fut")
    print("Current Value of BankNIFTY: " + str(bn_ltp))
    
    who_triggered = "NONE"
    
    #Amit's Test
    ##bn_ltp = 21949
    
    if(bn_ltp>buy_above):
        print("Buy Order executed at: " +str(bn_ltp)+". Entry Time is "+ str(run_time)+".")
        who_triggered = "BUY"
        stop_loss = bn_ltp*(.995)
        target = bn_ltp*(1.02)
    
    if(bn_ltp<sell_below):
        print("Sell Order executed at: " +str(bn_ltp)+". Entry Time is "+ str(run_time)+".")
        who_triggered = "SELL"
        stop_loss = bn_ltp*(1.005)
        target = bn_ltp*(.98)
    
    if(who_triggered != "NONE"):
        entry_price = run_time
        entry_price = bn_ltp
        print("Stop Loss is: " + str(stop_loss)+".")
        print("Target is: " + str(target)+".")
        break        
        
    time.sleep(10)

#Managing the Trade

while True:
    bn_ltp = nse_quote_ltp("BANKNIFTY","latest","Fut")
    print("Current Value of BankNIFTY: " + str(bn_ltp))
    
    exit_time = run_time
    exit_price = bn_ltp
        
    if(who_triggered == "BUY"):
        
        if(bn_ltp>target):
            print("Target hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Profit: "+str(abs(entry_price-exit_price))+" points.")
            break
            
        if(bn_ltp<stop_loss):
            print("Stop Loss hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Loss: "+str(abs(entry_price-exit_price))+" points.")
            break
    
    if(who_triggered == "SELL"):
        
        if(bn_ltp<target):
            print("Target hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Profit: "+str(abs(entry_price-exit_price))+" points.")
            break
            
        if(bn_ltp>stop_loss):
            print("Stop Loss hit at: "+ str(bn_ltp)+". Exit Time is "+ str(run_time)+".")
            print("Net Loss: "+str(abs(entry_price-exit_price))+" points.")
            break
