# %% [markdown]
# <a href="https://colab.research.google.com/github/aeron7/BankNIFTY-Golden-Ratio-Strategy/blob/master/Tutorial%20Notebooks%20(NSEPython%20Server)/BankNIFTY_Golden_Ratio_Strategy_Part_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nsepythonserver

# %%
from nsepythonserver import *

# %%
#https://nbviewer.org/
#https://nbviewer.org/github/aeron7/BankNIFTY-Golden-Ratio-Strategy/blob/master/Tutorial%20Notebooks/BankNIFTY%20Golden%20Ratio%20Strategy%20-%20Part%20II.ipynb
historical_data = nsefetch('https://www.nseindia.com/api/historical/fo/derivatives?&expiryDate=24-SEP-2020&instrumentType=FUTIDX&symbol=BANKNIFTY')
historical_data
# Out:
# {'data': [],
#  'meta': {'symbol': 'BANKNIFTY',
#   'expiryDate': '24-SEP-2020',
#   'instrumentType': 'FUTIDX',
#   'year': '2020',
#   'fromDate': '08-08-2023',
#   'toDate': '08-09-2023'}}

# %%
historical_data = nsefetch('https://www.nseindia.com/api/historical/fo/derivatives?&expiryDate=28-SEP-2023&instrumentType=FUTIDX&symbol=BANKNIFTY')
historical_data
# Out:
# {'data': [{'_id': '64f9ceee029da316b3374536',
#    'FH_INSTRUMENT': 'FUTIDX',
#    'FH_SYMBOL': 'BANKNIFTY',
#    'FH_EXPIRY_DT': '28-Sep-2023',
#    'FH_STRIKE_PRICE': '0.00',
#    'FH_OPTION_TYPE': 'XX',
#    'FH_MARKET_TYPE': 'N',
#    'FH_OPENING_PRICE': '44605.30',
#    'FH_TRADE_HIGH_PRICE': '45099.95',
#    'FH_TRADE_LOW_PRICE': '44538.25',
#    'FH_CLOSING_PRICE': '45045.15',
#    'FH_LAST_TRADED_PRICE': '45053.20',
#    'FH_PREV_CLS': '44644.05',
#    'FH_SETTLE_PRICE': '45045.15',
#    'FH_TOT_TRADED_QTY': '2863050',
#    'FH_TOT_TRADED_VAL': '128371792714.50',
#    'FH_OPEN_INT': '2022390',
#    'FH_CHANGE_IN_OI': '-52125.00',
#    'FH_MARKET_LOT': '15',
#    'FH_TIMESTAMP': '07-Sep-2023',
#    'TIMESTAMP': '2023-09-06T18:30:00.000Z',
#    'FH_UNDERLYING_VALUE': 44878.35,
#    'CALCULATED_PREMIUM_VAL': 128371792714.5},
#   {'_id': '64f88f3d029da316b31f418d',
#    'FH_INSTRUMENT': 'FUTIDX',
#    'FH_SYMBOL': 'BANKNIFTY',
#    'FH_EXPIRY_DT': '28-Sep-2023',
# ...

# %%
historical_data = historical_data['data']

# %%
historical_data = pd.DataFrame(historical_data)
historical_data
# Out:
#                          _id FH_INSTRUMENT  FH_SYMBOL FH_EXPIRY_DT  \
# 0   64f9ceee029da316b3374536        FUTIDX  BANKNIFTY  28-Sep-2023
# 1   64f88f3d029da316b31f418d        FUTIDX  BANKNIFTY  28-Sep-2023
# 2   64f7264d029da316b3030a98        FUTIDX  BANKNIFTY  28-Sep-2023
# 3   64f5ddb7029da316b3ea5b54        FUTIDX  BANKNIFTY  28-Sep-2023
# 4   64f1e933029da316b3b1ecf2        FUTIDX  BANKNIFTY  28-Sep-2023
# 5   64f0bb5d029da316b39da3f5        FUTIDX  BANKNIFTY  28-Sep-2023
# 6   64ef42f1029da316b380ee35        FUTIDX  BANKNIFTY  28-Sep-2023
# 7   64edefa0029da316b3688ae9        FUTIDX  BANKNIFTY  28-Sep-2023
# 8   64eca339029da316b3518699        FUTIDX  BANKNIFTY  28-Sep-2023
# 9   64e8ce94029da316b31fe3b1        FUTIDX  BANKNIFTY  28-Sep-2023
# 10  64e76bc1029da316b307fec1        FUTIDX  BANKNIFTY  28-Sep-2023
# 11  64e60e0c029da316b3effa4d        FUTIDX  BANKNIFTY  28-Sep-2023
# 12  64e4af6f029da316b3d7c5a3        FUTIDX  BANKNIFTY  28-Sep-2023
# ...

# %%
historical_data.head(5)
# Out:
#                         _id FH_INSTRUMENT  FH_SYMBOL FH_EXPIRY_DT  \
# 0  64f9ceee029da316b3374536        FUTIDX  BANKNIFTY  28-Sep-2023
# 1  64f88f3d029da316b31f418d        FUTIDX  BANKNIFTY  28-Sep-2023
# 2  64f7264d029da316b3030a98        FUTIDX  BANKNIFTY  28-Sep-2023
# 3  64f5ddb7029da316b3ea5b54        FUTIDX  BANKNIFTY  28-Sep-2023
# 4  64f1e933029da316b3b1ecf2        FUTIDX  BANKNIFTY  28-Sep-2023
#
#   FH_STRIKE_PRICE FH_OPTION_TYPE FH_MARKET_TYPE FH_OPENING_PRICE  \
# 0            0.00             XX              N         44605.30
# 1            0.00             XX              N         44710.00
# 2            0.00             XX              N         44750.00
# 3            0.00             XX              N         44160.05
# 4            0.00             XX              N         44268.70
#
#   FH_TRADE_HIGH_PRICE FH_TRADE_LOW_PRICE  ... FH_SETTLE_PRICE  \
# 0            45099.95           44538.25  ...        45045.15
# ...

# %%
previous_day_high = historical_data['FH_TRADE_HIGH_PRICE'].iloc[0]

# %%
previous_day_low = historical_data['FH_TRADE_LOW_PRICE'].iloc[0]

# %%
previous_day_high
# Out:
# '45099.95'

# %%
previous_day_low
# Out:
# '44538.25'
